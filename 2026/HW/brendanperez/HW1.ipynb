# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/Homework2026/2026/HW/brendanperez/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PHY386 Homework 1:
# Learning outcome: get familiar with basic fomatting and coding.
#
# Tags: **Google Colab, Jupyter, python, markdown, github, AI**

# %% [markdown]
# Create a new Google Colab notebook and generate the following headings in text cells (level in brackets):
#
# - Basic formatting examples (2)
# - Coding excercises (2)
# - How to include external media (3)
# - Learn that LLMs (AI) respond deterministically to structured prompts (3)

# %% [markdown]
# ## Basic formatting examples (7 points)
#
# make a numbered list that includes 5 things you want to learn in this class

# %% [markdown]
# 1. Github/Version Control
# 2. More advanced python
# 3. Using more python libraries
# 4. How we can apply python knowledge for physics
# 5. Maybe languages other than python and how they are used differently

# %% [markdown]
# ### How to include external media (7 points)
# - add a picture of your favorite scientist
# - include a caption that lists the source of the picture
# - write one sentence why this is your favorite scientist
# - use markdown formatting to emphasize the scientists name
# - add an equation the scientitst used by embedding $\LaTeX$ code
# - close the paragraph with an emoji

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Marie_Curie_c._1920s.jpg/960px-Marie_Curie_c._1920s.jpg width="50%">
#
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Marie_Curie_c._1920s.jpg/960px-Marie_Curie_c._1920s.jpg
#
# ***Marie Curie*** is my favorite scientist for how pivotal her work was for future physicists after her, and her inspirational life story. 👍
#
# Curie's Law, discovered by her husband Pierre
#
# $M=\chi{}H, \chi{}=\frac{C}{T}$

# %% [markdown]
# ## Coding Exercises Total: (total 21 points)
#
# 1. **Print "Hello, World!"** (1 point)
#    - Learn how to print text in Python and modify it so it says "Hello Class!".
#
# 6. **Formatting** (3 points)
#    - use a formatting string to include the number "02026.00" in a print statement with 1 leading and 2 trailing zeroes.
#
# 2. **Variables and Data Types** (2 points)
#    - generate three variable: a string, an integer, and a float, and print their values.
#
# 3. **Basic Math Operations** (2 points)
#    - Perform addition, subtraction, multiplication, division, and modulus operations.
#
# 4. **Conditional Statements** (2 points)
#    - Use if-else conditions to check if an integer is the square root of another integer.
#
# 5. **Loops: Counting with a For Loop** (2 points)
#    - Use a for loop to print numbers and modify it to show odd numbers.
#
# 7. **Functions: Simple Calculator** (2 points)
#    - Define and call a function to perform basic string operations.
#
# 8. **Lists: Average Calculator** (2 points)
#    - Use lists to calculate the median of a set of numbers.
#
# 9. **Dictionaries: Fruits** (2 points)
#    - Store and print diffferent pizza types using dictionaries.
#
# 10. **File Handling: Writing to a File** (3 points)
#     - Write user input to a file and modify it to read back the contents.

# %%
print("Hello Class!")
# Out:
# Hello Class!

# %%
print(f"{2026.00:08.2f}")
# Out:
# 02026.00

# %%
_string = "String"
_int = 1
_float = 1.0

print(_string , _int , _float)
# Out:
# String 1 1.0

# %%
print(1 + 1 - 1 * 1 / 1 % 1)
print(1 + 1 - 1 * 1 // 1 % 1)
# Out:
# 2.0
# 2

# %%
def isSquareRoot(i, n):
  if i == (n**(1/2)):
    return(True)
  return(False)

# %%
for i in range(10):
  if i % 2 == 1:
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
def concadinateString(string1, string2):
  return(string1 + string2)

# %%
import numpy as np

def median(l):
  return(np.median(l))

# %%
pizza = {
    'plain' : ['sauce','cheese'],
    'sausage' : ['sauce', 'cheese', 'sausage'],
    'pepperoni' : ['sauce','cheese','pepperoni']
}

print(pizza['plain'])
# Out:
# ['sauce', 'cheese']

# %%
def writeToFile(text):
  with open("File.txt", 'a') as file:
    file.write(text)
  with open("File.txt") as file:
    print(file.read())

# %% [markdown]
# ## Publish your work (4 points)
#
# ### Have your work checked by a LLM (AI)
#
# Upload or paste your notebook to a LLM from the list below:
# - ChatGPT https://chat.openai.com/
# - Google Gemini https://gemini.google.com/
# - Claude https://claude.ai/
# - Microsoft Copilot https://copilot.microsoft.com/
# - Perplexity AI https://www.perplexity.ai/
#
# and let the LLM (AI) generate a commit message with the following requirements:
#
# Required poem structure:
# - Exactly **4 stanzas**
# - Each stanza has **2 lines**
# - Each line has **8–12 words**
# - Rhyme scheme: AABB
# - Tone: playful, curious, and optimistic
# - Style: written as if by a very enthusiastic physics student learning programming
#
# Required content:
# - Stanza 1: summarize your learning goals
# - Stanza 2: mention your favorite scientist by name
# - Stanza 3: include the equation in LaTeX form
# - Stanza 4: how easy is it to write a fun commit message

# %% [markdown]
# I want to master Python, physics, coding every day
# I hope to build cool programs that help me learn and play
#
# Marie Curie inspires me, her discoveries still shine bright
# Her courage and persistence make experiments feel right
#
# I write $M=\chi H,\ \chi=\frac{C}{T}$ in code today
# Turning equations into programs helps concepts stay
#
# Writing a fun commit message turned out easy and fun
# With prompts and GitHub pushes, homework feels quickly done

# %% [markdown]
# ### Upload (push) to Github
#
# 1. Click: *File*>*Save a copy on github*
# 2.
#     - choose as repository: *ubsuny/PHY386*
#     - branch: *Homework2026*
#     - File path: *2026/HW1/YourGitHubUserName/HW1.ipynb*
#     - Commit message: *Use the poem created earlier, e.g.*
# ```text
# I learn Python basics, plotting graphs, thinking like scientist delight
# I dream of coding tools to explore nature with delight
# Albert Einstein inspires me, curious equations dancing with light
# His playful thought experiments make learning physics feel light
# I proudly write $F=ma$ in notebooks, code, and mind tonight
# Equations turn to programs, gravity simulated very nicely tonight
# Writing a fun commit message feels surprisingly easy tonight
# With prompts and smiles, I push to GitHub happily tonight 😊
# ```
# poem created by ChatGPT
#
#     - check: *include a link to google colab*
#
# ![This is how it should look like](https://github.com/ubsuny/PHY386/blob/2fa7ce16d6179245739a71fa389358d801141b13/figures/UploadtoGitHub2026.png?raw=true "Upload to GitHub")
