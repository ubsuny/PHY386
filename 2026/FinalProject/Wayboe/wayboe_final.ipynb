# %% [markdown]
# <a href="https://colab.research.google.com/github/Wayboe/PHY386/blob/wayboe-final/2026/FinalProject/Wayboe/wayboe_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/Homework2026/2026/FinalProject/Final_05_GaiaVariables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Final Project — Topic 5: Gaia Variable-Star Classification (42 pts)
#
# ## Learning Outcomes
# - Compose an ADQL join across two Gaia DR3 tables using `astroquery.gaia`.
# - Handle severe class imbalance in a multi-class classification problem.
# - Train the four HW5/HW6 classifiers (Decision Tree, k-Nearest Neighbors, Random Forest, Multi-Layer Perceptron) on real stellar data and compare their strengths.
# - Interpret a multi-class confusion matrix in terms of the physics of stellar variability.
# - Overlay the Leavitt period–luminosity relation on your predictions to test whether the classifier recovers textbook stellar physics.

# %% [markdown]
# ## GitHub Workflow
# Fork → `yourname-final` → PR into `Homework2026`. Reviewer `@laserlab`, milestone `Final-2026`.
#
# ## Heads-up on the Gaia archive
# The Gaia archive occasionally reports transient instability — the ADQL server may prompt "the archive is unstable and we are working to resolve this issue." If your query hangs, wait 5 minutes and retry, or reduce `SELECT TOP 20000` to a smaller number.

# %% [markdown]
# ## Background: Why Stars Vary
#
# Most stars are boringly steady. The ones that aren't come in several physically distinct flavors — and those flavors are the cornerstone of modern astrophysics.
#
# - **Pulsating variables** (RR Lyrae, Cepheids, δ Scuti, long-period variables / Miras) — the whole star expands and contracts. For Cepheids and RR Lyrae, the pulsation period is tightly tied to luminosity (the **Leavitt / period–luminosity relation**), which makes them "standard candles" in cosmology.
# - **Eclipsing binaries** — two stars in mutual orbit; the light curve dips when one blocks the other. Periods range from hours to years.
# - **Rotational variables** — spotted stars modulated by rotation.
# - **Cataclysmic variables / eruptive** — novae, dwarf novae: violent brightness changes.
#
# Gaia DR3's `gaiadr3.vari_classifier_result` table assigns each source a `best_class_name` label drawn from this zoo, plus a confidence score. The task: recover those labels from only the mean photometry and astrometry — no light curves.
#
# Why is that interesting? Because the labels encode different *physics* (pulsation vs. eclipsing geometry vs. rotation), and those different physics imprint themselves on the stars' color, luminosity, and distance. If a classifier can separate RR Lyrae from Cepheids using just position in the H–R diagram, it's effectively rediscovering the instability strip.

# %%
# !pip install astroquery
# Out:
# Requirement already satisfied: astroquery in /usr/local/lib/python3.12/dist-packages (0.4.11)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from astroquery) (2.0.2)
# Requirement already satisfied: astropy>=5.0 in /usr/local/lib/python3.12/dist-packages (from astroquery) (7.2.0)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.12/dist-packages (from astroquery) (2.32.4)
# Requirement already satisfied: beautifulsoup4>=4.8 in /usr/local/lib/python3.12/dist-packages (from astroquery) (4.13.5)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.12/dist-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/local/lib/python3.12/dist-packages (from astroquery) (25.7.0)
# Requirement already satisfied: pyvo>=1.5 in /usr/local/lib/python3.12/dist-packages (from astroquery) (1.8.1)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.0->astroquery) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.0->astroquery) (0.2026.4.20.0.58.15)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.0->astroquery) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.0->astroquery) (26.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.8->astroquery) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.8->astroquery) (4.15.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib>=0.999->astroquery) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery) (6.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery) (2026.4.22)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=15.0->astroquery) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=15.0->astroquery) (10.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery) (3.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({
    'font.size': 11, 'axes.labelsize': 11, 'axes.titlesize': 11,
    'xtick.labelsize': 11, 'ytick.labelsize': 11, 'legend.fontsize': 11,
})

# %% [markdown]
# ## Worked Example: ADQL Join
# The query below joins the variability-classifier table with `gaia_source` on `source_id` and pulls the features we'll classify on. We restrict to `best_class_score > 0.9` so the labels are reliable, and cap at 20,000 rows to stay polite to the server.

# %%
from astroquery.gaia import Gaia

QUERY = """
SELECT TOP 5000
  v.source_id, v.best_class_name, v.best_class_score,
  g.phot_g_mean_mag, g.bp_rp, g.parallax, g.pmra, g.pmdec,
  g.phot_variable_flag
FROM gaiadr3.vari_classifier_result AS v
JOIN gaiadr3.gaia_source AS g USING (source_id)
WHERE v.best_class_score > 0.9
  AND g.parallax IS NOT NULL
  AND g.bp_rp IS NOT NULL
"""

job = Gaia.launch_job_async(QUERY)
df = job.get_results().to_pandas()
print(f"{len(df)} sources")
print(df['best_class_name'].value_counts().head(10))
df.head()
# Out:
# INFO:astroquery:Query finished.
# INFO: Query finished. [astroquery.utils.tap.core]
# 5000 sources
# best_class_name
# LPV                2208
# ECL                1773
# AGN                 396
# RR                  162
# RS                  136
# DSCT|GDOR|SXPHE     114
# SOLAR_LIKE          112
# YSO                  31
# BE|GCAS|SDOR|WR      22
# S                    16
# Name: count, dtype: int64
#              source_id best_class_name  best_class_score  phot_g_mean_mag  \
# 0  5902303732175465088             ECL          0.968600        19.409748
# 1  5902311497499016832             ECL          0.927220        17.728340
# 2  5902456770469914368             ECL          0.911632        17.044622
# 3  5902495145971338880             LPV          0.966324        13.264520
# 4  5902567919895740032             LPV          0.920234        13.781874
#
#       bp_rp  parallax       pmra     pmdec phot_variable_flag
# 0  1.597588  0.120161  -2.497686 -2.766499           VARIABLE
# 1  1.508539  0.643607 -10.467644 -4.883639           VARIABLE
# 2  1.050047  0.004910  -5.496808 -3.835621           VARIABLE
# 3  3.387250  0.064964  -8.073285 -3.749761           VARIABLE
# 4  3.038055  0.005366  -4.690069 -0.503685           VARIABLE

# %% [markdown]
# ## Part 1 — Class Balance and Feature Engineering (10 pts)
#
# ### Task 1.1 — Pick your classes (3 pts)
# The variability classifier has many classes, very unevenly populated. Restrict to the top N most common — 4 to 7 is sensible — and drop the rest. Report how many stars per class you keep.
#
# ### Task 1.2 — Add an absolute-magnitude feature (4 pts)
# Compute:
# $$M_G = G + 5 \log_{10}(\varpi_\text{mas}) - 10$$
# where $G$ is `phot_g_mean_mag` and $\varpi_\text{mas}$ is `parallax` in milliarcseconds. Drop rows with non-positive parallax. This is your most physically informative feature — it places each star on the H–R diagram.
#
# ### Task 1.3 — Feature list (3 pts)
# Final feature vector per star: `[bp_rp, abs_mag, pmra, pmdec]`. Label: `best_class_name`. Any additional features you want to try (e.g. total proper motion $\sqrt{\mu_\alpha^2 + \mu_\delta^2}$, galactic latitude) — justify briefly.

# %%
# Part 1 Code

df_clean = df.copy()
df_clean = df_clean[df_clean["parallax"] > 0].dropna(
    subset=["phot_g_mean_mag", "bp_rp", "parallax", "pmra", "pmdec", "best_class_name"]
)


N_CLASSES = 5
top_classes = df_clean["best_class_name"].value_counts().head(N_CLASSES).index
df_top = df_clean[df_clean["best_class_name"].isin(top_classes)].copy()


df_top["abs_mag"] = (
    df_top["phot_g_mean_mag"] + 5 * np.log10(df_top["parallax"]) - 10
)


df_top["pm_total"] = np.sqrt(df_top["pmra"]**2 + df_top["pmdec"]**2)

features = ["bp_rp", "abs_mag", "pmra", "pmdec"]
X = df_top[features]
y = df_top["best_class_name"]

print("Classes kept:")
print(y.value_counts())

print("\nFeatures used:")
print(features)

df_top.head()
# Out:
# Classes kept:
# best_class_name
# LPV           1878
# ECL           1579
# RS             136
# RR             129
# SOLAR_LIKE     112
# Name: count, dtype: int64
#
# Features used:
# ['bp_rp', 'abs_mag', 'pmra', 'pmdec']
#              source_id best_class_name  best_class_score  phot_g_mean_mag  \
# 0  5902303732175465088             ECL          0.968600        19.409748
# 1  5902311497499016832             ECL          0.927220        17.728340
# 2  5902456770469914368             ECL          0.911632        17.044622
# 3  5902495145971338880             LPV          0.966324        13.264520
# 4  5902567919895740032             LPV          0.920234        13.781874
#
#       bp_rp  parallax       pmra     pmdec phot_variable_flag   abs_mag  \
# 0  1.597588  0.120161  -2.497686 -2.766499           VARIABLE  4.808571
# 1  1.508539  0.643607 -10.467644 -4.883639           VARIABLE  6.771445
# 2  1.050047  0.004910  -5.496808 -3.835621           VARIABLE -4.500090
# 3  3.387250  0.064964  -8.073285 -3.749761           VARIABLE -2.672122
# 4  3.038055  0.005366  -4.690069 -0.503685           VARIABLE -7.569891
#
#     pm_total
# 0   3.727191
# 1  11.550823
# 2   6.702752
# 3   8.901609
# 4   4.717037

# %% [markdown]
# In the future I would want to try and use galatic latitude, because it is another intersting measurment to see how far away each star is from the galatic equator of the milky way. This is another good classifer to seperate the star data.

# %% [markdown]
# ## Part 2 — Train the Four Classifiers (14 pts)
#
# Use the full HW5 + HW6 lineup: Decision Tree, k-Nearest Neighbors, Random Forest, Multi-Layer Perceptron.
#
# ### Task 2.1 — Pipeline (3 pts)
# Train/test split stratified on the label. Standardize features with `StandardScaler`. Address class imbalance either by downsampling large classes or by passing `class_weight='balanced'` (where supported). State which you chose and why.
#
# ### Task 2.2 — Train and evaluate (8 pts, 2 per classifier)
# For each of the four, report test-set accuracy **and** macro-F1 (which penalizes ignoring rare classes). Plot the confusion matrix.
#
# ### Task 2.3 — Summary table (3 pts)
#
# | Classifier | Accuracy | Macro-F1 | Notes |
# |------------|----------|----------|-------|
# | Decision Tree | ... | ... | ... |
# | k-Nearest Neighbors | ... | ... | ... |
# | Random Forest | ... | ... | ... |
# | Multi-Layer Perceptron | ... | ... | ... |

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    accuracy_score
)
from sklearn.pipeline import Pipeline

# %%
#Part 2 Code
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

models = {
    "Decision Tree": DecisionTreeClassifier(
        max_depth=8,
        class_weight="balanced",
        random_state=42
    ),
    "k-Nearest Neighbors": KNeighborsClassifier(
        n_neighbors=7
    ),
    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        max_depth=12,
        class_weight="balanced",
        random_state=42
    ),
    "Multi-Layer Perceptron": MLPClassifier(
        hidden_layer_sizes=(64, 32),
        max_iter=500,
        random_state=42
    )
}

results = []
predictions = {}

for name, model in models.items():
    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", model)
    ])

    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    predictions[name] = y_pred

    acc = accuracy_score(y_test, y_pred)
    macro_f1 = f1_score(y_test, y_pred, average="macro")

    results.append({
        "Classifier": name,
        "Accuracy": acc,
        "Macro-F1": macro_f1,
        "Notes": "Used scaled features; balanced weights where supported"
    })

    print(f"{name}")
    print(f"Accuracy: {acc:.3f}")
    print(f"Macro-F1: {macro_f1:.3f}")
    print()

    cm = confusion_matrix(y_test, y_pred, labels=pipe.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_)

    fig, ax = plt.subplots(figsize=(6, 4))
    disp.plot(ax=ax, xticks_rotation=45, cmap="Blues")
    ax.set_title(f"{name} Confusion Matrix")
    plt.tight_layout()
    plt.show()

summary_table = pd.DataFrame(results)
summary_table
# Out:
# Decision Tree
# Accuracy: 0.804
# Macro-F1: 0.591
# k-Nearest Neighbors
# Accuracy: 0.902
# Macro-F1: 0.500
# Random Forest
# Accuracy: 0.900
# Macro-F1: 0.680
# Multi-Layer Perceptron
# Accuracy: 0.923
# Macro-F1: 0.705
#                Classifier  Accuracy  Macro-F1  \
# 0           Decision Tree  0.803962  0.591179
# 1     k-Nearest Neighbors  0.901981  0.500319
# 2           Random Forest  0.899896  0.680406
# 3  Multi-Layer Perceptron  0.922836  0.705074
#
#                                                Notes
# 0  Used scaled features; balanced weights where s...
# 1  Used scaled features; balanced weights where s...
# 2  Used scaled features; balanced weights where s...
# 3  Used scaled features; balanced weights where s...

# %% [markdown]
# I chose to use the class_weight=balanced because it helps balance the the data sets by adjusting the weights proportional to class frequencies. This was well used for the Decision Tree and Random Forest models.

# %% [markdown]
# ## Part 3 — Physics-in-the-H–R-Diagram (10 pts)
#
# ### Task 3.1 — Colored H–R diagram (4 pts)
# Plot $M_G$ (y, inverted) vs. $B_P - R_P$ (x), colored by **true** class. Does each variability class occupy a recognizable region? RR Lyrae should land near the instability strip; Miras in the upper-right red-giant corner; eclipsing binaries spread across the main sequence.
#
# ### Task 3.2 — Classifier decision regions (4 pts)
# Take a 2D slice (fix proper motions at their median values) and plot the Random Forest's decision regions in ($B_P - R_P$, $M_G$). Do the regions match the physical zones from Task 3.1?
#
# ### Task 3.3 — Physics discussion (2 pts)
# In 4–6 sentences: which classes are most-confused-with-which in the confusion matrix, and does that match where they overlap on the H–R diagram?

# %%
# Part 3: your code here
fig, ax = plt.subplots(figsize=(9, 7))

for class_name in df_top["best_class_name"].unique():
    subset = df_top[df_top["best_class_name"] == class_name]
    ax.scatter(
        subset["bp_rp"],
        subset["abs_mag"],
        s=12,
        alpha=0.6,
        label=class_name
    )

ax.invert_yaxis()
ax.set_xlabel(r"$B_P - R_P$")
ax.set_ylabel(r"$M_G$")
ax.set_title("H-R Diagram Colored by True Class")
ax.legend()
plt.tight_layout()
plt.show()

bp_min, bp_max = df_top["bp_rp"].min() - 0.3, df_top["bp_rp"].max() + 0.3
mg_min, mg_max = df_top["abs_mag"].min() - 0.5, df_top["abs_mag"].max() + 0.5

bp_grid, mg_grid = np.meshgrid(
    np.linspace(bp_min, bp_max, 300),
    np.linspace(mg_min, mg_max, 300)
)

pmra_med = df_top["pmra"].median()
pmdec_med = df_top["pmdec"].median()

grid_df = pd.DataFrame({
    "bp_rp": bp_grid.ravel(),
    "abs_mag": mg_grid.ravel(),
    "pmra": pmra_med,
    "pmdec": pmdec_med
})


rf_classifier = models["Random Forest"]
rf_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", rf_classifier)
])
rf_pipeline.fit(X_train, y_train)
rf = rf_pipeline


y_pred_rf = rf.predict(X_test)

Z = rf.predict(grid_df)
classes = rf.classes_
Z_num = np.array([np.where(classes == z)[0][0] for z in Z])
Z_num = Z_num.reshape(bp_grid.shape)

fig, ax = plt.subplots(figsize=(9, 7))

ax.contourf(bp_grid, mg_grid, Z_num, alpha=0.25)

for class_name in classes:
    subset = df_top[df_top["best_class_name"] == class_name]
    ax.scatter(
        subset["bp_rp"],
        subset["abs_mag"],
        s=10,
        alpha=0.5,
        label=class_name
    )

ax.invert_yaxis()
ax.set_xlabel(r"$B_P - R_P$")
ax.set_ylabel(r"$M_G$")
ax.set_title("Random Forest Decision Regions in the H-R Diagram")
ax.legend()
plt.tight_layout()
plt.show()


cm = confusion_matrix(y_test, y_pred_rf, labels=classes)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)

fig, ax = plt.subplots(figsize=(9, 7))
disp.plot(ax=ax, xticks_rotation=45, cmap="Blues")
ax.set_title("Random Forest Confusion Matrix")
plt.tight_layout()
plt.show()

confusion_df = pd.DataFrame({
    "True class": y_test.values,
    "Predicted class": y_pred_rf
})

mistakes = confusion_df[confusion_df["True class"] != confusion_df["Predicted class"]]

print("Most common confusions:")
print(mistakes.value_counts().head(10))
# Out:
# Most common confusions:
# True class  Predicted class
# ECL         RS                 34
# SOLAR_LIKE  ECL                19
# RS          ECL                13
# ECL         SOLAR_LIKE         12
# RR          ECL                11
# ECL         RR                  6
# RR          RS                  1
# Name: count, dtype: int64

# %% [markdown]
# 3.2
# For the most part the regions were very similar to to the plot I made for 3.1. The boundries for the regions do get very jagged towards the middle because of the random forest model, but overall the data makes sense for what I saw in 3.1.
#
# 3.3
# The classes that get confused the most are the ones that all overlap on the H-V diagram. Classes like the ECL, RS, Solar Like, and RR. These classes with similar colors and absolute magintude are bound to be confused in this model. Which makes sense since these are all 4 classes that overlap with each, while the LVP which is seprerate has no confusion.

# %% [markdown]
# ## Part 4 — Stretch: The Leavitt Law (8 pts)
#
# If you kept Cepheids and/or RR Lyrae in your class set, you can test whether the classifier has implicitly learned the **period–luminosity relation** — the Leavitt law that made Cepheids the standard candle underpinning modern distance measurements.
#
# The challenge: periods are in a separate Gaia table (`gaiadr3.vari_cepheid`, `gaiadr3.vari_rrlyrae`). You need a second ADQL query to pull them.
#
# ### Task 4.1 — Query Cepheid or RR Lyrae periods (4 pts)
# ```sql
# SELECT source_id, pf, p1_o
# FROM gaiadr3.vari_cepheid
# ```
# Join on `source_id` with your main DataFrame.
#
# ### Task 4.2 — Period–luminosity plot (4 pts)
# Plot $M_G$ vs. $\log_{10}(P / \mathrm{day})$ for Cepheids (and/or RR Lyrae). Fit a line. Compare your slope and intercept to the published Leavitt relation. Color points by classifier-predicted class — do misclassified stars fall off the relation?

# %%
# Part 4 (optional stretch): your code here

from astroquery.gaia import Gaia
from sklearn.linear_model import LinearRegression

query = """
SELECT source_id, pf, p1_o
FROM gaiadr3.vari_rrlyrae -- Changed to vari_rrlyrae
"""

job = Gaia.launch_job_async(query)
period_table = job.get_results()
period_df = period_table.to_pandas()



cepheid_df = df_top.merge(period_df, on="source_id", how="inner")


cepheid_df["period"] = cepheid_df["pf"].fillna(cepheid_df["p1_o"])


cepheid_df = cepheid_df.dropna(subset=["period", "abs_mag"])
cepheid_df = cepheid_df[cepheid_df["period"] > 0].copy()

cepheid_df["log_period"] = np.log10(cepheid_df["period"])

print(cepheid_df[["source_id", "best_class_name", "period", "log_period", "abs_mag"]].head())


cepheid_df["predicted_class"] = rf.predict(cepheid_df[features])


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7), sharey=True)


for class_name in cepheid_df["best_class_name"].unique():
    subset = cepheid_df[cepheid_df["best_class_name"] == class_name]
    ax1.scatter(
        subset["log_period"],
        subset["abs_mag"],
        s=20,
        alpha=0.7,
        label=f"True: {class_name}"
    )

ax1.invert_yaxis()
ax1.set_xlabel(r"$\	ext{log}_{10}(P / \text{day})$")
ax1.set_ylabel(r"$M_G$ (Absolute G-band Magnitude)")
ax1.set_title("Period-Luminosity Relation (True Class)")
ax1.legend()


for class_name in cepheid_df["predicted_class"].unique():
    subset = cepheid_df[cepheid_df["predicted_class"] == class_name]
    ax2.scatter(
        subset["log_period"],
        subset["abs_mag"],
        s=20,
        alpha=0.7,
        label=f"Predicted: {class_name}"
    )

ax2.invert_yaxis()
ax2.set_xlabel(r"$\	ext{log}_{10}(P / \text{day})$")
ax2.set_title("Period-Luminosity Relation (Predicted Class)")
ax2.legend()


rr_lyrae_subset = cepheid_df[cepheid_df["best_class_name"] == "RR"]
if not rr_lyrae_subset.empty:
    X_pl = rr_lyrae_subset[["log_period"]]
    y_pl = rr_lyrae_subset["abs_mag"]

    lin_reg = LinearRegression()
    lin_reg.fit(X_pl, y_pl)


    log_period_range = np.linspace(X_pl["log_period"].min(), X_pl["log_period"].max(), 100)
    predicted_mag = lin_reg.predict(log_period_range.reshape(-1, 1))

    ax1.plot(log_period_range, predicted_mag, color='red', linestyle='--', label=f'Linear Fit: {lin_reg.coef_[0]:.2f}x + {lin_reg.intercept_:.2f}')
    ax1.legend()
    ax2.plot(log_period_range, predicted_mag, color='red', linestyle='--', label=f'Linear Fit: {lin_reg.coef_[0]:.2f}x + {lin_reg.intercept_:.2f}')
    ax2.legend()

    print(f"\nLinear Regression for RR Lyrae (log(Period) vs Abs Mag):")
    print(f"  Slope: {lin_reg.coef_[0]:.4f}")
    print(f"  Intercept: {lin_reg.intercept_:.4f}")
else:
    print("No RR Lyrae stars found in cepheid_df to fit a period-luminosity relation.")

plt.tight_layout()
plt.show()
# Out:
# INFO:astroquery:Query finished.
# INFO: Query finished. [astroquery.utils.tap.core]
#              source_id best_class_name    period  log_period   abs_mag
# 0  6030113124151164800              RR  0.500739   -0.300388 -0.308824
# 1  6027892321150588928              RR  0.513913   -0.289110  3.525558
# 2  2053453246098423424              RR  0.290291   -0.537167  1.033809
# 3  6030060798569339776              RR  0.471192   -0.326802  1.467437
# 4  6030063753571601792              RR  0.445721   -0.350937  1.271590
#
# Linear Regression for RR Lyrae (log(Period) vs Abs Mag):
#   Slope: 2.1768
#   Intercept: 1.6024
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Submission
# **Good commit** ✅: `Add multi-class confusion matrix and HR-diagram decision regions`
#
# **Bad commit** ❌: `fix`, `wip`
#
# ### Checklist
# - [ ] Notebook in `2026/FinalProject/<yourname>/`
# - [ ] Runs top-to-bottom on a fresh kernel
# - [ ] Type annotations and NumPy docstrings on your functions
# - [ ] All plots labeled (HR diagram with inverted y-axis!)
# - [ ] Tasks sum to ~42 points
# - [ ] PR into `Homework2026`, reviewer `@laserlab`, milestone `Final-2026`
# - [ ] AI usage disclosed

# %% [markdown]
# ## Resources
# - [`astroquery.gaia`](https://astroquery.readthedocs.io/en/latest/gaia/gaia.html)
# - [Gaia DR3 variability tables](https://gea.esac.esa.int/archive/documentation/GDR3/Gaia_archive/chap_datamodel/sec_dm_variability_tables/)
# - [`vari_classifier_result` column dictionary](https://gea.esac.esa.int/archive/documentation/GDR3/Gaia_archive/chap_datamodel/sec_dm_variability_tables/ssec_dm_vari_classifier_result.html)
# - Leavitt, H. S. & Pickering, E. C. (1912). *Periods of 25 variable stars in the Small Magellanic Cloud.* Harvard College Observatory Circular 173.
# - Clementini, G. et al. (2023). *Gaia Data Release 3: Specific processing and validation of all-sky RR Lyrae and Cepheid stars.* A&A 674, A18.
