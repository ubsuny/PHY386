# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/Homework2026/HW/Wayboe/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PHY 386 HW1
# Shane Marshall
#
# What I want to learn from this Course
#
#
# 1.   I want to learn how I can relate coding to the physics I have learned throughout my time at UB
# 2.   How to use code to plot data
# 3. How to use code to understand and sort all sorts of numbers
# 4. I want to see how code can maybe even make physics eaiser than on paper
# 5. Learn about different kinds of coding languages in general
#
# ![download (3).jpg](data:image/jpeg;base64,...)
#
# This is **Albert Einstein** (obviously), he is my favorite because he came up with a lot of special relativity, which is very intriguing to me.
#
# Energy-Momentum Relation: $E^2 = pc^2 + (mc^2)^2$
#
# ![image.png](data:image/png;base64,...)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello Class!")
# Out:
# Hello Class!

# %%
print("02026.00")
# Out:
# 02026.00

# %%
import random

# To generate a random integer between two numbers (e.g., 1 and 100)
random_integer = random.randint(1, 100)
print(random_integer)
# Out:
# 74

# %%
numbers = [1,2,1,3,1,4,2,4,10000]
mean = sum(numbers)/len(numbers)
print(mean)
# Out:
# 1113.111111111111

# %% [markdown]
# `sorted()`
# ```python
# sorted()
