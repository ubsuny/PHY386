# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/main/2025/Final/Final_Star_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computational Methods for Physicists Final Project
# ## Title: Star Classification by Color
# ### Duration: 14 Days (Start Date: Tuesday, April 29, 2025, Due Date: During finals week)
#
# ---
#
# ## 1. Introduction
#
# This is your final project for this class!
#
# In this project, you will analyze a FITS image of a star field to classify stars based on their color. By measuring the brightness of stars in different filters, you will determine their color indices and relate them to **spectral classes** (e.g., O, B, A, F, G, K, M). You will explore how star colors relate to their temperatures and physical properties.
#
# **Optional:** You may use a simple machine learning model to automate classification based on color indices.
#
# **Project Topic:** Photometric star classification.
#
# **Key Focus:** Color analysis, spectral classification, photometry.
#
# ---
#
# ## 2. Learning Objectives
#
# By completing this project, you will:
# - Learn to extract photometric data from a FITS image.
# - Understand how star color relates to spectral class and temperature.
# - Perform star classification based on color indices.
# - Optionally apply a simple machine learning model for classification.
# - Document your process clearly in a reproducible way.
# - Analyze star clusters using color indices to infer their age and composition.
#
# ---
#
# ## 3. Dataset Description
#
# **You will receive:**
# - A FITS image of a star field captured with your Seestar S30.
#
# The FITS image includes:
# - Metadata about the observation, including telescope and exposure details.
#
# You will use this image to extract photometric data in multiple filters (e.g., R, G, B) and analyze the color indices of stars within the field.
#
# **Optional:**
# - You may use a machine learning model to classify stars based on their color indices.
#
# ---
#
# ## 4. Project Tasks (Total: 28 Points)
#
# ### Task 1: Data Exploration and Visualization (6 points)
#
# - Load the FITS image and inspect its contents.
# - Display the image with appropriate scaling to visualize the star field.
# - Identify and label several stars for analysis.
# - Generate histograms of pixel values to assess brightness distribution.
# - **Note:** Focus on stars that are part of the star cluster to ensure consistent distance and age assumptions.
#
# ### Task 2: Physical Context and Research (3 points)
#
# - Explain the concept of color indices (e.g., B-V) and their significance in determining stellar temperatures.
# - Discuss the relationship between color indices and spectral classification.
# - Explore how different stellar populations (e.g., main sequence, giants) exhibit distinct color characteristics.
# - **Importance for Star Clusters:** Understanding color indices is crucial for analyzing star clusters, as they allow astronomers to infer the age, composition, and evolutionary state of the cluster. Since stars in a cluster are at approximately the same distance and formed around the same time, their color indices can reveal insights into the cluster's properties and history.
#
# ### Task 3: Data Processing and Feature Extraction (13 points)
#
# - Extract photometric data for selected stars in multiple filters (e.g., R, G, B).
# - Calculate color indices (e.g., B-V) for each star.
# - Use the **SIMBAD catalog** to retrieve the **spectral classifications** of the same stars.
# - Compare your calculated color indices with the spectral classifications from SIMBAD to assess consistency.
# - Plot color-magnitude diagrams to visualize the distribution of stars.
# - Optionally: Apply machine learning techniques to classify stars based on their color indices.
#
# ### Task 4: Modeling and Analysis (6 points)
#
# - Fit theoretical models (e.g., main sequence) to the color-magnitude diagram.
# - Estimate the distances to the stars based on their positions in the diagram.
# - Discuss the implications of your findings in the context of stellar populations.
#
# ---
#
# ## 5. Tools and Libraries (6 points)
#
# You are encouraged to use:
# - **Astropy** for handling FITS files and metadata.
# - **Matplotlib** for plotting color-magnitude diagrams and histograms.
# - **Scikit-learn** for implementing machine learning models (if applicable).
# - **NumPy** for numerical computations.
#
# Proper use of tools and libraries will be evaluated on:
# - Correct use of relevant packages for the task.
# - Efficient coding practices.
# - Use of appropriate data structures and functions.
#
# ---
#
# ## 6. Submission Instructions (8 points)
#
# - Submit your completed notebook (.ipynb) and any additional files.
# - Submit into the **`2025/Final/YourGitHubUserName`** folder in the repository.
# - Deadline: During finals week.
#
# ### Submission Quality Guidelines:
# - Use **docstrings** for all functions.
# - Write **clear and readable code**.
# - Include **comments** explaining non-obvious steps.
# - Organize notebook with **markdown cells** explaining each section.
# - Ensure that all **code runs without errors**.
# - Use **figures and visualizations** where appropriate.
#
# ---
#
# ## 7. Grading Breakdown
# - **Tasks Total:** 28 pts
# - **Tools Use:** 6 pts
# - **Submission Quality:** 8 pts
# - **Total:** **42 Points**
#
# ---
