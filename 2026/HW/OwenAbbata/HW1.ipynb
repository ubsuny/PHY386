# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/Homework2026/2026/HW/OwenAbbata/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PHY386 HW1
# Owen Abbata Owenabba@buffalo.edu

# %% [markdown]
# Things I want to learn in PHY386:
# 1.   How to use code like a physist for high level physics problems
# 2.   How to make graphs in a Python language
# 3. How to use Ai in coding to make the process easier
# 4. How to use coding in a high school enviroment to help prepare students for coding in college
# 5. Learn about the difference types of coding for the different types and branches of physics

# %% [markdown]
# ![Screenshot 2026-02-03 112036.png](data:image/png;base64,...)
#
# https://en.wikipedia.org/wiki/File:Sir_Ernest_Rutherford_LCCN2014716719_-_restoration1.jpg
#
# **Ernest Rutherford** is my favorite scientist because in one of my classes I had to pretend to be him on a podcast

# %% [markdown]
# \ LaTex
#
# 😃
