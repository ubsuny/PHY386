# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/main/2026/HW/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# <!-- Note: Starting with this homework, Codespaces is the recommended environment. Colab still works but will be phased out. -->

# %% [markdown]
# # Homework 3: Sensor Data Analysis and GitHub Workflow
#
# ## Your Personal Physics Experiment
#
# Modern smartphones contain sophisticated sensor arrays capable of capturing high-quality physical measurements. Each student will perform a **different experiment** using a specific sensor, then analyze the raw data using Python.
#
# **New in 2026:** You will also learn the **GitHub feature-branch workflow** by submitting this homework via pull request on the GitHub website (no command line needed).
#
# ---
#
# ## Learning Outcomes
#
# - Export and analyze **raw sensor data** from phyphox
# - Read and preprocess data using pandas
# - Fit a physics model specific to your experiment using scipy
# - Create publication-quality visualizations with matplotlib
# - **Submit homework via pull request using GitHub's web interface** (new)
# - **Work in GitHub Codespaces** (optional with bonus)
#
# ---
#
# ## Total Points: 42 (+5 bonus)

# %% [markdown]
# ## Step 0: Choose Your Experiment
#
# **BEFORE YOU START:** Claim your experiment using GitHub Issues.
#
# ### How to Claim (First Come, First Served):
#
# 1. **Open the experiment selection issue:**
#    - Go to: [HW3 Experiment Selection Issue](https://github.com/ubsuny/PHY386/issues) (link will be posted when HW3 is published)
#    - Read the available experiments and watch the demo videos
#
# 2. **Create YOUR tracking issue:**
#    - Click **"New issue"**
#    - Select **"HW3 Experiment Claim"** template
#    - Fill in:
#      - Title: `HW3 - [Experiment Name] - @yourusername`
#      - Choose your experiment from dropdown
#      - Add your approach/plan (optional)
#    - Submit the issue
#
# 3. **Reserve your experiment:**
#    - Go back to the main experiment selection issue
#    - Comment: `I'm claiming [Experiment Name]. Tracking in issue #[your-issue-number]`
#    - This reserves your experiment so others know it's taken
#
# 4. **Track your progress:**
#    - Use your tracking issue to check off tasks as you complete them
#    - Paste commit messages there to show your workflow
#    - Ask questions in comments if you get stuck
#
# ---
#
# ### Available Experiments:
#
# Each experiment has a **YouTube demo video** and **forum discussion** with tips from real users:
#
# - 🛗 **Elevator Pressure** — Barometric formula fit
#   [🎥 YouTube Demo](https://www.youtube.com/watch?v=y-goBtfuXAM) | [💬 Forum](https://phyphox.org/forums/showthread.php?tid=1605)
#
# - 🪑 **Rotating Chair** — Angular damping fit
#   [🎥 YouTube Demo](https://www.youtube.com/watch?v=lLCf05Hc83Y) | [💬 Forum](https://phyphox.org/forums/showthread.php?tid=409)
#
# - 🧲 **Magnet Distance** — Dipole field (1/r³) fit
#   [🎥 YouTube Demo](https://www.youtube.com/watch?v=TS0zw1ecy6A) | [💬 Forum](https://phyphox.org/forums/showthread.php?tid=485)
#
# - 💡 **Flashlight Intensity** — Inverse square law fit
#   ⚠️ **Android only** (not available on iPhones) | [💬 Forum](https://phyphox.org/forums/showthread.php?tid=809)
#
# - 🔊 **Sound Decay** — Exponential damping fit
#   [🎥 YouTube Demo](https://www.youtube.com/watch?v=uoUm34CnHdE) | [💬 Forum](https://phyphox.org/forums/showthread.php?tid=803)
#
# - 👋 **Hand Proximity** — Exponential saturation fit
#   [📖 Sensor Info](https://phyphox.org/sensors/)
#
# - 💧 **Water Bottle Squeeze** — Hooke's law fit
#   (Uses same pressure sensor as elevator)
#
# ---
#
# ### Why Different Experiments?
#
# - You'll see **diverse physics** across the class
# - Everyone practices a **different fitting technique**
# - More interesting for presentations
# - Learn to work with **raw sensor data** (phyphox has built-in analysis, but we're doing it ourselves)
# - Professional experiment documentation using GitHub Issues
#
# ---
#
# **Once you've claimed your experiment and opened your tracking issue, continue to Part 1 below.**

# %% [markdown]
# ## Part 1: Experimental Setup with phyphox (10 points)
#
# ### Task A: Install and Configure phyphox
#
# 1. **Download phyphox**:
#    - [iOS App Store](https://apps.apple.com/us/app/phyphox/id1127319693)
#    - [Google Play Store](https://play.google.com/store/apps/details?id=de.rwth_aachen.phyphox)
#
# 2. **Find your sensor** (based on the table above):
#    - Open phyphox
#    - Tap the **"+ Custom"** or **"Simple"** tab (NOT the pre-made experiments)
#    - Select your assigned sensor (Pressure, Gyroscope, Magnetometer, etc.)
#
# 3. **Why raw data?**
#    - phyphox has pre-built experiments with automatic analysis
#    - We're skipping those to learn **how** the analysis works
#    - You'll export the raw CSV and do the fitting yourself
#
# ---
#
# ### Task B: Perform Your Experiment
#
# Follow the instructions for **your** experiment:
#
# #### **Pressure (Elevator or Bottle)**
# - Open "Pressure" sensor
# - Press ▶ to start recording
# - Ride elevator up/down OR squeeze a sealed water bottle
# - Record 30–60 seconds
# - Export CSV: `time, pressure`
#
# #### **Gyroscope (Rotating Chair)**
# - Open "Gyroscope" sensor
# - Sit in office chair, start recording
# - Spin chair and let it slow down naturally
# - Record until nearly stopped (~30 sec)
# - Export CSV: `time, gyro_x, gyro_y, gyro_z`
#
# #### **Magnetometer (Magnet Distance)**
# - Open "Magnetometer" sensor
# - Place phone on table, start recording
# - Slowly move a magnet from far (~50 cm) to near (~5 cm)
# - Keep magnet along one axis (e.g., approach from the side)
# - Export CSV: `time, mag_x, mag_y, mag_z`
#
# #### **Light (Flashlight Distance)**
# - Open "Light" sensor
# - In a dark room, start recording
# - Move flashlight from close to far (or vice versa)
# - Try to keep flashlight aimed at sensor
# - Export CSV: `time, illuminance`
#
# #### **Microphone (Sound Decay)**
# - Open "Audio Amplitude" or raw "Microphone"
# - Tap a tuning fork or wine glass to make it ring
# - Hold phone near the sound source
# - Record ~10 seconds as sound fades
# - Export CSV: `time, amplitude`
#
# #### **Proximity (Hand Approach)**
# - Open "Proximity" sensor
# - Start recording
# - Move hand slowly toward screen from ~20 cm away
# - Stop just before touching
# - Export CSV: `time, distance`
#
# ---
#
# ### Task C: Export and Upload
#
# 1. **Export data**:
#    - In phyphox, tap the **⋮** menu → **Export Data**
#    - Choose **CSV** format
#    - Save file as `yourusername_hw3_data.csv`
#
# 2. **Upload to your workspace**:
#    - **Colab:** Use file upload button
#    - **Codespaces (+5 bonus):** Drag file into `2026/HW/yourusername/` folder
#
# ---
#
# ### Deliverable
#
# - [ ] CSV file with raw sensor data included in your homework folder
# - [ ] Brief description (2-3 sentences): What you did, any challenges

# %% [markdown]
# ## Part 2: Data Analysis with pandas (8 points)
#
# ### Task: Load and Preprocess
#
# 1. **Read CSV** using `pandas.read_csv()`
# 2. **Inspect**:
#    - Print first 10 rows
#    - Check for missing values (`df.isnull().sum()`)
#    - Verify time spacing (is it uniform?)
# 3. **Trim data**:
#    - Remove initial/final sections where experiment wasn't running
#    - For example: cut first 2 seconds (setup time) and last 2 seconds
# 4. **Select relevant column**:
#    - If you have `mag_x, mag_y, mag_z`, pick the axis with largest change
#    - If you have `gyro_x, gyro_y, gyro_z`, calculate magnitude or pick dominant axis
#
# ---
#
# ### Deliverable
#
# - [ ] Code that loads and cleans data
# - [ ] Print summary: mean, std, min, max of your measured quantity
# - [ ] Explanation: what did you trim and why?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Load your data
# df = pd.read_csv('yourusername_hw3_data.csv')

# Inspect
# print(df.head(10))
# print(df.describe())

# %% [markdown]
# ## Part 3: Model Fitting (8 points)
#
# ### Task A: Define Your Physics Model
#
# Based on **your assigned experiment**, define the appropriate model function:
#
# ---
#
# #### **Pressure (Elevator) → Barometric Formula**
#
# Pressure vs altitude:
# $$
# P(h) = P_0 e^{-h/H}
# $$
#
# where $P_0$ is sea-level pressure, $H \approx 8500$ m is scale height.
#
# Convert time to height using $h = v \cdot t$ (elevator speed $v \approx 1$ m/s).
#
# **Fit:** `P(t) = P0 * exp(-v*t / H)`
#
# **Report:** $P_0$ and $v$ (elevator speed)
#
# ---
#
# #### **Gyroscope (Chair) → Exponential Damping**
#
# Angular velocity decays due to friction:
# $$
# \omega(t) = \omega_0 e^{-\beta t}
# $$
#
# **Fit:** `omega(t) = omega0 * exp(-beta * t)`
#
# **Report:** $\omega_0$ (initial angular velocity) and $\beta$ (damping constant)
#
# ---
#
# #### **Magnetometer (Magnet) → Dipole Field**
#
# Magnetic field from a dipole:
# $$
# B(r) = \frac{\mu_0 m}{4\pi r^3}
# $$
#
# Simplify: $B(r) = A / r^3$
#
# You need to convert time to distance (measure your hand speed separately, or fit $r(t) = r_0 + v t$).
#
# **Fit:** `B(t) = A / (r0 + v*t)**3`
#
# **Report:** $A$ (dipole strength) and $v$ (approach speed)
#
# ---
#
# #### **Light (Flashlight) → Inverse Square Law**
#
# Illuminance decreases with distance:
# $$
# I(r) = \frac{I_0}{r^2}
# $$
#
# **Fit:** `I(t) = I0 / (r0 + v*t)**2`
#
# **Report:** $I_0$ (source intensity) and approach speed $v$
#
# ---
#
# #### **Microphone (Sound Decay) → Exponential Damping**
#
# Sound amplitude decays:
# $$
# A(t) = A_0 e^{-\gamma t}
# $$
#
# **Fit:** `A(t) = A0 * exp(-gamma * t)`
#
# **Report:** $A_0$ (initial amplitude) and $\gamma$ (decay rate)
#
# ---
#
# #### **Proximity (Hand Approach) → Exponential Saturation**
#
# Sensor reading approaches saturation:
# $$
# d(t) = d_{\infty} + (d_0 - d_{\infty}) e^{-t/\tau}
# $$
#
# **Fit:** `d(t) = d_inf + (d0 - d_inf) * exp(-t / tau)`
#
# **Report:** $d_0$ (starting distance) and $\tau$ (time constant)
#
# ---
#
# ### Task B: Perform the Fit
#
# 1. Define your model function in Python
# 2. Use `scipy.optimize.curve_fit`
# 3. Extract fitted parameters and uncertainties from covariance matrix
#
# ---
#
# ### Task C: Plot Data + Fit
#
# Create a plot showing:
# - Raw data (scatter plot)
# - Fitted curve (solid line)
# - Axis labels with units
# - Legend
# - Title indicating your experiment
#
# ---
#
# ### Deliverable
#
# - [ ] Model function defined in code
# - [ ] `curve_fit` executed successfully
# - [ ] Plot with data and fit overlaid
# - [ ] Reported parameters with uncertainties (e.g., $\beta = 0.15 \pm 0.02$ s⁻¹)
# - [ ] Brief interpretation: Does the fit make sense physically?

# %%
# Example for exponential decay (gyroscope or sound):
# def model(t, omega0, beta):
#     return omega0 * np.exp(-beta * t)

# popt, pcov = curve_fit(model, time, angular_velocity)
# omega0_fit, beta_fit = popt
# uncertainties = np.sqrt(np.diag(pcov))

# plt.figure(figsize=(8, 5))
# plt.scatter(time, angular_velocity, label='Data', alpha=0.6)
# plt.plot(time, model(time, *popt), 'r-', label='Fit', linewidth=2)
# plt.xlabel('Time (s)')
# plt.ylabel('Angular velocity (rad/s)')
# plt.legend()
# plt.title('Rotating Chair: Angular Velocity Decay')
# plt.show()

# print(f"ω₀ = {omega0_fit:.3f} ± {uncertainties[0]:.3f} rad/s")
# print(f"β = {beta_fit:.3f} ± {uncertainties[1]:.3f} s⁻¹")

# %% [markdown]
# ## Part 4: Advanced Visualization (8 points)
#
# ### Task: Multi-Panel Figure
#
# Create a **2×2 subplot grid**:
#
# 1. **Top-left:** Raw data vs time
# 2. **Top-right:** Fitted model vs time (overlay)
# 3. **Bottom-left:** Residuals (data - model)
# 4. **Bottom-right:** Histogram of residuals
#
# **Requirements:**
# - Shared x-axis (time) for top and bottom-left
# - Proper axis labels with units
# - Titles for each subplot
# - Use `plt.subplots(2, 2, figsize=(12, 8))`
#
# **Reference:** [Matplotlib subplots documentation](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)
#
# ---
#
# ### Deliverable
#
# - [ ] 2×2 figure with all four plots
# - [ ] Residuals centered around zero (good fit)
# - [ ] Histogram approximately Gaussian (if fit is good)

# %%
# fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# # Top-left: raw data
# axs[0, 0].scatter(time, data, alpha=0.5)
# axs[0, 0].set_ylabel('Measured value')
# axs[0, 0].set_title('Raw Data')

# # Top-right: fit overlay
# axs[0, 1].scatter(time, data, alpha=0.5, label='Data')
# axs[0, 1].plot(time, fitted, 'r-', label='Fit')
# axs[0, 1].set_ylabel('Measured value')
# axs[0, 1].set_title('Data + Fit')
# axs[0, 1].legend()

# # Bottom-left: residuals
# residuals = data - fitted
# axs[1, 0].scatter(time, residuals, alpha=0.5)
# axs[1, 0].axhline(0, color='k', linestyle='--')
# axs[1, 0].set_xlabel('Time (s)')
# axs[1, 0].set_ylabel('Residuals')
# axs[1, 0].set_title('Residuals (Data - Fit)')

# # Bottom-right: histogram of residuals
# axs[1, 1].hist(residuals, bins=20, edgecolor='black')
# axs[1, 1].set_xlabel('Residual value')
# axs[1, 1].set_ylabel('Count')
# axs[1, 1].set_title('Residuals Distribution')

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Part 5: Error Analysis (8 points)
#
# ### Task: Uncertainty Quantification
#
# 1. **Parameter uncertainties**:
#    - Extract from `curve_fit` covariance matrix: `np.sqrt(np.diag(pcov))`
#    - Report fitted values ± uncertainty
#
# 2. **Sensor resolution**:
#    - Check phyphox documentation or your CSV for precision
#    - Example: Pressure typically ±0.1 hPa, gyroscope ±0.01 rad/s
#    - How does sensor noise affect your fit?
#
# 3. **Systematic errors**:
#    - **Pressure:** Local weather, sensor calibration
#    - **Gyroscope:** Phone not level, chair friction varies
#    - **Magnetometer:** Nearby metal objects, Earth's field
#    - **Light:** Ambient light interference
#    - **Microphone:** Background noise
#    - **Proximity:** Non-linear sensor response
#
# 4. **Comparison to theory**:
#    - Does your result match expected values?
#    - Example: Barometric scale height should be ~8500 m
#    - Example: Sound decay rate depends on room acoustics (no "correct" value, but should be positive)
#
# ---
#
# ### Deliverable
#
# - [ ] Fitted parameters with uncertainties reported
# - [ ] Discussion of sensor limitations (2-3 sentences)
# - [ ] Comparison to expected/theoretical values (if applicable)
# - [ ] List 2-3 sources of systematic error in your experiment

# %% [markdown]
# ## Part 6: GitHub Workflow — Submit via Pull Request (10 points)
#
# ### NEW: Feature Branch Workflow (No Command Line!)
#
# This homework introduces the **feature-branch workflow** using only the **GitHub website**. No terminal commands needed.
#
# ---
#
# ## ⚠️ IMPORTANT: Commit Messages Matter!
#
# **You will lose points for non-descriptive commit messages.**
#
# ### Good Commit Messages ✅
# - `Add data loading and preprocessing with pandas`
# - `Implement exponential decay model for sound data`
# - `Fix time axis trimming to remove setup period`
# - `Create 2x2 subplot visualization with residuals`
#
# ### Bad Commit Messages ❌
# - `update` (What did you update?)
# - `fix` (What did you fix?)
# - `stuff` (What stuff?)
# - `asdf` (Not descriptive at all)
# - `Final version` (Too vague)
#
# ### Why Commit Messages Matter:
# - They document **what changed and why**
# - They help reviewers understand your workflow
# - They're essential in professional software development
# - They help **you** remember what you did when you revisit code later
#
# **Tip:** Write commit messages as if you're explaining to a classmate what you just did.
#
# ---
#
# ## Step-by-Step Instructions (GitHub Web Interface)
#
# ### Step 1: Go to the Repository
#
# 1. Open your browser and go to: [https://github.com/ubsuny/PHY386](https://github.com/ubsuny/PHY386)
# 2. Make sure you're logged into GitHub
#
# ---
#
# ### Step 2: Create Your Feature Branch
#
# 1. Click the **branch dropdown** (says "main" or "Homework2026")
# 2. Make sure **"Homework2026"** is selected
# 3. In the branch dropdown, type: `yourusername-hw3` (e.g., `jsmith-hw3`)
# 4. Click **"Create branch: yourusername-hw3 from Homework2026"**
#
# ![Create Branch](https://docs.github.com/assets/cb-32358/mw-1440/images/help/branches/branch-selection-dropdown.webp)
#
# ---
#
# ### Step 3: Upload Your Files
#
# 1. Make sure you're on **your branch** (check the dropdown says `yourusername-hw3`)
# 2. Navigate to: `2026/HW/yourusername/`
#    - If your folder doesn't exist yet, create it by clicking **"Add file" → "Create new file"**
#    - Name it `yourusername/.gitkeep` and commit (this creates the folder)
# 3. Click **"Add file" → "Upload files"**
# 4. Drag and drop:
#    - `HW3.ipynb` (your completed notebook)
#    - `yourusername_hw3_data.csv` (your raw data)
# 5. **At the bottom, write a DESCRIPTIVE commit message:**
#    - Good: `Add HW3 notebook with gyroscope analysis and raw data`
#    - Bad: `upload files`
# 6. Make sure **"Commit directly to yourusername-hw3 branch"** is selected
# 7. Click **"Commit changes"**
#
# ---
#
# ### Step 4: Open a Pull Request
#
# 1. After uploading, GitHub shows a yellow banner: **"yourusername-hw3 had recent pushes"**
# 2. Click the green **"Compare & pull request"** button
#
# **OR** manually:
# 1. Click the **"Pull requests"** tab at the top
# 2. Click **"New pull request"**
# 3. Set:
#    - **Base:** `Homework2026`
#    - **Compare:** `yourusername-hw3`
# 4. Click **"Create pull request"**
#
# ---
#
# ### Step 5: Fill Out the PR Template
#
# 1. **Change the title** to: `HW3 - 2026 - yourusername`
#
# 2. **Fill out the description** (the template appears automatically):
#    - Check **one** box under "Type of Submission":
#      - `[ ]` In progress (if you want feedback)
#      - `[x]` Final submission (if you're done)
#    - Check all boxes in the Checklist
#    - Fill in "What I implemented" section
#    - Delete "Questions or notes" if you have none
#    - Delete "AI Usage" if you didn't use AI
#
# 3. **Add label** (right sidebar):
#    - Click **"Labels"**
#    - Select: `homework-in-progress` OR `homework-final`
#
# 4. **Assign reviewer** (right sidebar):
#    - Click **"Reviewers"**
#    - Type: `laserlab` and select
#
# 5. **Set milestone** (right sidebar):
#    - Click **"Milestone"**
#    - Select: `HW3-2026`
#
# 6. Click **"Create pull request"**
#
# ---
#
# ### Step 6: Respond to Feedback
#
# If the instructor requests changes:
#
# 1. Go back to the repository
# 2. Switch to **your branch** (`yourusername-hw3`)
# 3. Navigate to your notebook file
# 4. Click the **pencil icon** ("Edit this file")
# 5. Make the requested changes
# 6. **Scroll down and commit with a DESCRIPTIVE message:**
#    - Good: `Fix model function to use correct exponential form`
#    - Good: `Add missing uncertainty calculations for fit parameters`
#    - Bad: `fix`
# 7. The PR updates automatically
# 8. Go to your PR and **leave a comment**: "Ready for re-review @laserlab"
#
# ---
#
# ### Deliverable
#
# - [ ] Feature branch created with correct naming (`yourusername-hw3`)
# - [ ] Files uploaded to `2026/HW/yourusername/` in your branch
# - [ ] **ALL commit messages are descriptive** (points will be deducted for vague messages)
# - [ ] PR opened with title: `HW3 - 2026 - yourusername`
# - [ ] PR template filled out completely
# - [ ] Correct label added (`homework-in-progress` or `homework-final`)
# - [ ] Reviewer assigned (`@laserlab`)
# - [ ] Milestone set (`HW3-2026`)
# - [ ] Responded to at least one round of feedback (if requested)
#
# ---
#
# ### Troubleshooting
#
# **Issue:** "I don't see the branch dropdown"
# - **Fix:** Make sure you're on the main repository page, not inside a file
#
# **Issue:** "I can't create a branch"
# - **Fix:** You need to be added as a collaborator. Contact the instructor.
#
# **Issue:** "My files aren't showing up"
# - **Fix:** Make sure you uploaded to **your branch**, not to `main` or `Homework2026`
#
# **Issue:** "The PR template didn't appear"
# - **Fix:** Scroll down in the PR description box — it should be there. If not, copy it from `.github/pull_request_template.md`

# %% [markdown]
# ## Bonus: GitHub Codespaces (5 points)
#
# ### Optional: Complete This Homework in Codespaces
#
# Instead of Google Colab, try GitHub Codespaces:
#
# 1. Go to [https://github.com/ubsuny/PHY386](https://github.com/ubsuny/PHY386)
# 2. Click **"Code"** → **"Codespaces"** tab
# 3. Click **"Create codespace on Homework2026"**
# 4. Wait 2-3 minutes for environment setup
# 5. Work on your notebook in the browser-based VS Code
# 6. Upload your CSV file via drag-and-drop into the file explorer
# 7. All git operations (branch, commit, PR) can be done through the VS Code interface
#
# **Why Codespaces?**
# - Persistent environment (picks up where you left off)
# - Full git integration (no manual uploads)
# - Professional IDE experience
# - Required for HW5+
#
# **Deliverable for +5 bonus:**
# - [ ] Indicate in your PR description that you used Codespaces
# - [ ] (Codespaces commits show in git history automatically)

# %% [markdown]
# ## Grading Rubric
#
# | Part | Points | Criteria |
# |------|--------|----------|
# | 1. Experimental Setup | 10 | Correct sensor used, raw data exported, CSV included, experiment described |
# | 2. Data Preprocessing | 8 | Data loaded, cleaned, trimmed, summary statistics provided |
# | 3. Model Fitting | 8 | Correct model for experiment, fit executed, parameters reported with units |
# | 4. Visualization | 8 | 2×2 subplot grid with data, fit, residuals, histogram |
# | 5. Error Analysis | 8 | Uncertainties calculated, sensor limits discussed, systematic errors listed |
# | 6. GitHub Workflow | 10 | Branch created, PR opened with correct format, labels/milestone/reviewer set |
# | **Bonus: Codespaces** | +5 | Used Codespaces for entire workflow |
# | **Total** | **42 (+5)** | |
#
# ---
#
# ## Due Date
#
# **TBD by instructor**
#
# Your PR must be opened by the deadline. You can continue to respond to feedback after the deadline.

# %% [markdown]
# ## Resources
#
# - [phyphox Documentation](https://phyphox.org/)
# - [phyphox Supported Sensors](https://phyphox.org/sensors/)
# - [pandas Documentation](https://pandas.pydata.org/docs/)
# - [scipy.optimize.curve_fit Guide](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html)
# - [Matplotlib Subplots](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)
# - [GitHub Pull Request Guide](https://docs.github.com/en/pull-requests/collaborating-with-pull-requests/proposing-changes-to-your-work-with-pull-requests/creating-a-pull-request)
